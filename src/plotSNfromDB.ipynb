# %%
import sqlite3
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('../out/sncat.db')
#creates an empty file

# %%
c = conn.cursor()

# %%
c.execute('SELECT * FROM mysncat')
data = c.fetchall()

# %%
import pandas as pd
df = pd.DataFrame(data=data)

# %%
df = df.rename(columns = {2:'SNID', 1:'MJD', 6: 't0', 10:'u', 11:'g', 12:'r', 13:'i', 14:'z', 15:'y'})

# %%
snids = np.unique(df.SNID)

# %%
def plotsnlc(SNID,ax):
    x = df[df.SNID == SNID]
    ax.plot(x.MJD, x.u, 'k+', label='u')
    ax.plot(x.MJD, x.g, 'b+', label='g')
    ax.plot(x.MJD, x.r, 'g+', label='r')
    ax.plot(x.MJD, x.i, 'y+', label='i')
    ax.plot(x.MJD, x.z, 'm+', label='z')
    ax.plot(x.MJD, x.y, 'r+', label='y')
    ax.plot(x.MJD, x.u, 'k-')
    ax.plot(x.MJD, x.g, 'b-')
    ax.plot(x.MJD, x.r, 'g-')
    ax.plot(x.MJD, x.i, 'y-')
    ax.plot(x.MJD, x.z, 'm-')
    ax.plot(x.MJD, x.y, 'r-')
    plt.legend(loc='best', numpoints=1)
    ax.invert_yaxis()
    return fig

# %%
fig, ax = plt.subplots()

# %%
plotsnlc(snids[0], ax)
# Out:
# /usr/local/manual/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:476: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
df[df.SNID==snids[1]]
# Out:
#               0        MJD    SNID        3         4       5           t0  \
# 1707  obshist19  570138.15  101379  0.08586  0.260861  0.4179  570236.2527
# 2040   obshist9  570141.15  101379  0.08586  0.260861  0.4179  570236.2527
# 2373   obshist3  570144.15  101379  0.08586  0.260861  0.4179  570236.2527
# 2710   obshist7  570147.15  101379  0.08586  0.260861  0.4179  570236.2527
# 3043   obshist5  570150.15  101379  0.08586  0.260861  0.4179  570236.2527
# 3387   obshist9  570153.15  101379  0.08586  0.260861  0.4179  570236.2527
# 3717   obshist2  570156.15  101379  0.08586  0.260861  0.4179  570236.2527
# 4081  obshist22  570159.15  101379  0.08586  0.260861  0.4179  570236.2527
# 4408   obshist3  570162.15  101379  0.08586  0.260861  0.4179  570236.2527
# 4765  obshist13  570165.15  101379  0.08586  0.260861  0.4179  570236.2527
# 5109  obshist10  570168.15  101379  0.08586  0.260861  0.4179  570236.2527
# 5460  obshist14  570171.15  101379  0.08586  0.260861  0.4179  570236.2527
# 5808   obshist8  570174.15  101379  0.08586  0.260861  0.4179  570236.2527
# 6177  obshist22  570177.15  101379  0.08586  0.260861  0.4179  570236.2527
# 6516   obshist3  570180.15  101379  0.08586  0.260861  0.4179  570236.2527
#
#              7       8         9        u   g        r        i        z  \
# 1707 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 2040 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 2373 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 2710 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 3043 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 3387 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 3717 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 4081 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 4408 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 4765 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 5109 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 5460 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 5808 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 6177 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
# 6516 -0.220991  1.6359  0.000014  48.2593 NaN  48.9149  49.1729  49.2859
#
#             y
# 1707  48.8325
# 2040  48.8325
# 2373  48.8325
# 2710  48.8325
# 3043  48.8325
# 3387  48.8325
# 3717  48.8325
# 4081  48.8325
# 4408  48.8325
# 4765  48.8325
# 5109  48.8325
# 5460  48.8325
# 5808  48.8325
# 6177  48.8325
# 6516  48.8325
